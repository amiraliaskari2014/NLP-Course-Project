# %% [markdown]
# # Assignment APIs tutorial

# %% [markdown]
# In this notebook we are using the python package "millionaire-client" to interact with the deployed application for the NLP assignment 2026.
#
# Required files:
# - Directory called "millionaire_client"
# - 1 colab notebook
#
# Both files must be saved in a directory in your Google Drive, for example:
# ```
# gDrive_home/
# ├── Colab Notebooks/
# │   └── NLP_assignment/
# │       ├── PoliMillionaire.ipynb <-- Your notebook
# │       └── millionaire_client/ <-- Directory provided
# ```

# %% [markdown]
# ### Sign up procedure
# Before showing you how the api work, you need to signup from a web browser.
# - Paste this link into your browser [http://131.175.15.22:51111/](http://131.175.15.22:51111/) this is where the demo is deployed
# - You will see a standard login/sign up screen, please click on sign up
# - In the "email" field please enter your politecnico email, you are allwed to create only 1 account using the same email you registered to the NLP course
# - Choose whever username/password you prefer (be creative ;))

# %% [markdown]
# ### Game interaction

# %% [markdown]
# Once you signed up, you can start interacting already from the api.
#
# First of all, let's connect your drive to this Colab Notebook

# %%
from google.colab import drive
import os
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Then we need to add our python package "millionaire_client" to the system path, so python can see it.

# %%
import sys
import os

# Define the path to the directory containing your package
package_parent_dir = '/content/gdrive/MyDrive/Colab Notebooks/NLP_assignment_api_client'

# Append to sys.path if it is not already present
if package_parent_dir not in sys.path:
    sys.path.append(package_parent_dir)

# Verify the path was added
print(sys.path)
# Out:
# ['/content', '/env/python', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.12/dist-packages/IPython/extensions', '/root/.ipython', '/content/gdrive/MyDrive/Colab Notebooks/NLP_assignment_api_client']

# %% [markdown]
# Let's import the client classes

# %%
import os

print(os.listdir())
# !unzip -o NLP_assignment_api_client.zip
# Out:
# ['.config', 'gdrive', 'NLP_assignment_api_client.zip', 'sample_data']
# Archive:  NLP_assignment_api_client.zip
#    creating: NLP_assignment_api_client/.ipynb_checkpoints/
#   inflating: NLP_assignment_api_client/millionaire_client/auth.py
#   inflating: NLP_assignment_api_client/millionaire_client/exceptions.py
#   inflating: NLP_assignment_api_client/millionaire_client/client.py
#   inflating: NLP_assignment_api_client/PoliMillionaire.ipynb
#   inflating: NLP_assignment_api_client/millionaire_client/competitions.py
#   inflating: NLP_assignment_api_client/millionaire_client/models.py
#   inflating: NLP_assignment_api_client/millionaire_client/leaderboard.py
#   inflating: NLP_assignment_api_client/millionaire_client/game.py
#   inflating: NLP_assignment_api_client/millionaire_client/base.py
#   inflating: NLP_assignment_api_client/millionaire_client/__pycache__/client.cpython-312.pyc
#   inflating: NLP_assignment_api_client/millionaire_client/__pycache__/game.cpython-312.pyc
#   inflating: NLP_assignment_api_client/millionaire_client/__pycache__/competitions.cpython-312.pyc
#   inflating: NLP_assignment_api_client/millionaire_client/__pycache__/base.cpython-312.pyc
#   inflating: NLP_assignment_api_client/millionaire_client/__pycache__/leaderboard.cpython-312.pyc
#   inflating: NLP_assignment_api_client/millionaire_client/__pycache__/exceptions.cpython-312.pyc
#   inflating: NLP_assignment_api_client/millionaire_client/__pycache__/models.cpython-312.pyc
#   inflating: NLP_assignment_api_client/millionaire_client/__pycache__/__init__.cpython-312.pyc
#   inflating: NLP_assignment_api_client/millionaire_client/__init__.py
#   inflating: NLP_assignment_api_client/millionaire_client/__pycache__/auth.cpython-312.pyc

# %%
# !ls
# Out:
# gdrive	NLP_assignment_api_client  NLP_assignment_api_client.zip  sample_data

# %%
import sys

sys.path.append(
    "/content/NLP_assignment_api_client"
)

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'NLP_assignment_api_client.zip', 'sample_data']

# %%
# !unzip -o NLP_assignment_api_client.zip
# Out:
# Archive:  NLP_assignment_api_client.zip
#    creating: NLP_assignment_api_client/.ipynb_checkpoints/
#   inflating: NLP_assignment_api_client/millionaire_client/auth.py
#   inflating: NLP_assignment_api_client/millionaire_client/exceptions.py
#   inflating: NLP_assignment_api_client/millionaire_client/client.py
#   inflating: NLP_assignment_api_client/PoliMillionaire.ipynb
#   inflating: NLP_assignment_api_client/millionaire_client/competitions.py
#   inflating: NLP_assignment_api_client/millionaire_client/models.py
#   inflating: NLP_assignment_api_client/millionaire_client/leaderboard.py
#   inflating: NLP_assignment_api_client/millionaire_client/game.py
#   inflating: NLP_assignment_api_client/millionaire_client/base.py
#   inflating: NLP_assignment_api_client/millionaire_client/__pycache__/client.cpython-312.pyc
#   inflating: NLP_assignment_api_client/millionaire_client/__pycache__/game.cpython-312.pyc
#   inflating: NLP_assignment_api_client/millionaire_client/__pycache__/competitions.cpython-312.pyc
#   inflating: NLP_assignment_api_client/millionaire_client/__pycache__/base.cpython-312.pyc
#   inflating: NLP_assignment_api_client/millionaire_client/__pycache__/leaderboard.cpython-312.pyc
#   inflating: NLP_assignment_api_client/millionaire_client/__pycache__/exceptions.cpython-312.pyc
#   inflating: NLP_assignment_api_client/millionaire_client/__pycache__/models.cpython-312.pyc
#   inflating: NLP_assignment_api_client/millionaire_client/__pycache__/__init__.cpython-312.pyc
#   inflating: NLP_assignment_api_client/millionaire_client/__init__.py
#   inflating: NLP_assignment_api_client/millionaire_client/__pycache__/auth.cpython-312.pyc

# %%
# !find NLP_assignment_api_client
# Out:
# NLP_assignment_api_client
# NLP_assignment_api_client/PoliMillionaire.ipynb
# NLP_assignment_api_client/millionaire_client
# NLP_assignment_api_client/millionaire_client/__init__.py
# NLP_assignment_api_client/millionaire_client/base.py
# NLP_assignment_api_client/millionaire_client/auth.py
# NLP_assignment_api_client/millionaire_client/competitions.py
# NLP_assignment_api_client/millionaire_client/__pycache__
# NLP_assignment_api_client/millionaire_client/__pycache__/competitions.cpython-312.pyc
# NLP_assignment_api_client/millionaire_client/__pycache__/exceptions.cpython-312.pyc
# NLP_assignment_api_client/millionaire_client/__pycache__/models.cpython-312.pyc
# NLP_assignment_api_client/millionaire_client/__pycache__/auth.cpython-312.pyc
# NLP_assignment_api_client/millionaire_client/__pycache__/leaderboard.cpython-312.pyc
# NLP_assignment_api_client/millionaire_client/__pycache__/game.cpython-312.pyc
# NLP_assignment_api_client/millionaire_client/__pycache__/client.cpython-312.pyc
# NLP_assignment_api_client/millionaire_client/__pycache__/base.cpython-312.pyc
# NLP_assignment_api_client/millionaire_client/__pycache__/__init__.cpython-312.pyc
# NLP_assignment_api_client/millionaire_client/models.py
# NLP_assignment_api_client/millionaire_client/leaderboard.py
# NLP_assignment_api_client/millionaire_client/game.py
# NLP_assignment_api_client/millionaire_client/exceptions.py
# NLP_assignment_api_client/millionaire_client/client.py
# NLP_assignment_api_client/.ipynb_checkpoints

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['.config', 'NLP_assignment_api_client.zip', 'NLP_assignment_api_client', 'sample_data']

# %%
import sys

sys.path.insert(
    0,
    "/content/NLP_assignment_api_client"
)

print(sys.path[0])
# Out:
# /content/NLP_assignment_api_client

# %%
import os

print(
    os.path.exists(
        "/content/NLP_assignment_api_client/millionaire_client"
    )
)
# Out:
# True

# %%
from millionaire_client.client import MillionaireClient
from millionaire_client.exceptions import AuthenticationError

print("IMPORT OK")
# Out:
# IMPORT OK

# %% [markdown]
# You can save your password in a Colab secret (the "key" icon on the tab on the left) and import it into your notebook.

# %%
pwd = "20Ashkriti00"

# %% [markdown]
# Now keep the API_URL as stated, but please change the username and password to be the ones you used during sign up session.

# %%
API_URL = "http://131.175.15.22:51111/"
username = "ashkriti"
password = "20Ashkriti00"

# %% [markdown]
# Now we can instantiate a MillionaireClient object and call the login method, which takes as parameters username and password.

# %%
client = MillionaireClient(API_URL)
try:
    user = client.login(username, password)
    print(f"\nWelcome, {user.username}! (Role: {user.role})")
except AuthenticationError as e:
    print(f"Login failed: {e}")
# Out:
# Welcome, ashkriti! (Role: student)

# %% [markdown]
# After login, the web page is showing you different types of competitions, for each of them you can choose to play a game or to see the leaderboard. For now let's list all of the.

# %%
# List available competitions
print("\n=== Available Competitions ===")
competitions = client.competitions.list_all()
for comp in competitions:
    print(f"  {comp.id}: {comp.name} ({comp.max_levels} questions)")
# Out:
# === Available Competitions ===
#   0: Entertainment (15 questions)
#   1: Ancient History and Politics (15 questions)
#   2: Science and Nature (15 questions)
#   3: Maths (15 questions)

# %%
# Choose a competition ID
comp_id = 1

# %%
# !pip install openai-whisper
# Out:
# Requirement already satisfied: openai-whisper in /usr/local/lib/python3.12/dist-packages (20250625)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (10.8.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (2.0.2)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (0.12.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (2.10.0+cpu)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (4.67.3)
# Requirement already satisfied: triton>=2 in /usr/local/lib/python3.12/dist-packages (from openai-whisper) (3.7.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->openai-whisper) (0.43.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken->openai-whisper) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken->openai-whisper) (2.32.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper) (2025.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2026.4.22)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->openai-whisper) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->openai-whisper) (3.0.3)

# %%
import whisper
model = whisper.load_model("medium")

print("Whisper loaded")
# Out:
# 100%|█████████████████████████████████████| 1.42G/1.42G [00:17<00:00, 89.9MiB/s]
# Whisper loaded

# %% [markdown]
# After choosing a competition, we can start a game! We can choose to start a game by calling `game = client.game.start(competition_id=comp_id)`. The object game is the one that is handling the game itself, we can call:
# - game.current_question.text : to know the current question in text format
# - game.current_level: to check the current level of difficulty of the question
# - game.current_question.options: to check the possible choices we have to answer the question
# - game.answer: to send to the server the answer we choose (the integer corresponding to our choice) and get the response (either correct or incorrect)
#
# WATCH OUT! Each question has a timer, you have maximum 30 seconds to answer the question. As of now, if you exceed the maximum allowed time, there is not a "push notification". You still have to submit your answer anyway and, even though the answer was correct, you will get a TimedOut response!

# %%
def play_game(game):
  # Play the game
  while game.in_progress:
      question = game.current_question
      if not question:
          print("No question available. Game may have ended.")
          break

      print(f"\n--- Level {game.current_level} ---")
      print(f"Q: {question.text}")
      print()

      for opt in question.options:
          print(f"  [{opt.id}] {opt.text}")

      # Get time remaining
      time_left = game.time_remaining
      if time_left:

          print(f"\nTime remaining: {time_left:.1f}s")

      # Get answer
      try:
          answer_input = input("\nYour answer (option ID): ").strip()
          answer_id = int(answer_input)
      except ValueError:
          print("Invalid input. Please enter a number.")
          continue

      # Submit answer
      result = game.answer(answer_id)

      if result.correct:
          print(" CORRECT!")
          if result.game_over:
              print(f"\n CONGRATULATIONS! You completed the game!")
              print(f" Final earnings: ${result.earned_amount:,.2f}")
          else:
              print(f" Earned so far: ${result.earned_amount:,.2f}")
      elif result.timed_out:
        print("TIMED OUT!")
        print(f"\n Game Over!")
        print(f" Final earnings: ${result.earned_amount:,.2f}")
      elif not result.correct:
          print(" WRONG ANSWER!")
          print(f"\n Game Over!")
          print(f" Final earnings: ${result.earned_amount:,.2f}")

  print("\n=== Game Summary ===")
  print(f"Reached Level: {game.current_level}")
  print(f"Total Earnings: ${game.earned_amount:,.2f}")

# %%
from millionaire_client.exceptions import GameError

# %%
# Start the game
print("\n=== Starting Game ===")
game = client.game.start(competition_id=comp_id)
print(f"Session ID: {game.session_id}")
print(f"Total number of questions: {game.state.competition.max_levels}")
print()
play_game(game)
# Out:
# === Starting Game ===
# Session ID: 186711
# Total number of questions: 15
#
#
# --- Level 1 ---
# Fetching question audio...
# ---------------------------------------------------------------------------
# GameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3507/1032316665.py in play_game(game)
#       7         try:
# ----> 8             question_audio = game.fetch_audio_question()
#       9             filename = (f"level_{game.current_level}_question.wav")
#
# /content/NLP_assignment_api_client/millionaire_client/game.py in fetch_audio_question(self)
#      84         if self.mode != "speech":
# ---> 85             raise GameError("Audio is only available in speech mode")
#      86         return self._client.get(
#
# GameError: Audio is only available in speech mode
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3507/1148272211.py in <cell line: 0>()
#       5 print(f"Total number of questions: {game.state.competition.max_levels}")
#       6 print()
# ----> 7 play_game(game)
#
# /tmp/ipykernel_3507/1032316665.py in play_game(game)
#      19             print("\nQUESTION:")
#      20             print(question_text)
# ---> 21         except GameError as e:
#      22             print(f"Error fetching question audio: {e}")
#      23             break
#
# NameError: name 'GameError' is not defined

# %%
# Show leaderboard position
lb = client.leaderboard.get(competition_id=comp_id, limit=10)
print(f"\n=== Leaderboard for {lb.competition.name} ===")
for i, entry in enumerate(lb.entries[:5], 1):
    marker = " <-- YOU" if entry.username == username else ""
    print(f"  {i}. {entry.username}: ${entry.score:,.2f} (Level {entry.reached_level}){marker}")

# %% [markdown]
#  ## Speech interaction

# %%
from IPython.display import Audio, display

# %%
def save_audio(data: bytes, filename: str):
    """Save audio bytes to a WAV file."""
    with open(filename, "wb") as f:
        f.write(data)
    print(f"  Saved: {filename}")

# %%
def play_game(game):
    while game.in_progress:
        print(f"\n--- Level {game.current_level} ---")

        # Fetch question audio
        print("Fetching question audio...")
        try:
            question_audio = game.fetch_audio_question()
            filename = (f"level_{game.current_level}_question.wav")
            save_audio(question_audio, filename)
            print("Question saved")
            display(Audio(question_audio))
            result = model.transcribe(
                filename,
                language="en",
                fp16=False
            )

            question_text = result["text"]

            print("\nQUESTION:")
            print(question_text)
        except GameError as e:
            print(f"Error fetching question audio: {e}")
            break

        # Fetch option audios sequentially (A, B, C, D)
        option_map = {}
        audios = []
        option_texts = []
        for i in range(4):
            letter = chr(65 + i)  # A, B, C, D
            print(f"Fetching option {letter} audio...")
            try:
                option_audio = game.fetch_audio_option_next()
                filename = (f"level_{game.current_level}_option_{letter}.wav")
                save_audio(option_audio, filename)
                audios.append(filename)

                continue

                print(
                    f"Option {letter}:",
                    result["text"]
                )
                option_text = result["text"]
                import re

                option_text = re.sub(
                    r"^Option\s+[A-D][,:.]?\s*",
                    "",
                    option_text
                ).strip()

                print(
                    f"Option {letter}:",
                    option_text
                )

                option_texts.append(
                    option_text
                )
                audios.append(option_audio)
            except GameError as e:
                print(f"Error fetching option audio: {e}")
                break

            # Store mapping for answer submission
            if game.current_question and i < len(game.current_question.options):
                option_map[letter] = game.current_question.options[i].id

        display(Audio(audios[0]),
                Audio(audios[1]),
                Audio(audios[2]),
                Audio(audios[3])) # Pardon this horrific hard-coded stuff, due to (even more horrific) ipykernel logic. ~Federico
        print("\nTranscribing...")

        option_texts=[]

        for i,file in enumerate(audios):

            result = model.transcribe(
                file,
                language="en",
                fp16=False
            )

            option_text=result["text"]

            import re

            option_text = re.sub(
                r"^Option\s*[A-D]\s*[\.\:\,]?\s*",
                "",
                option_text,
                flags=re.IGNORECASE
            ).strip()

            print(f"Option {chr(65+i)}:", option_text)

            option_texts.append(option_text)

        import json

        question_json = {
            "question": question_text,
            "options": {
                "A": option_texts[0],
                "B": option_texts[1],
                "C": option_texts[2],
                "D": option_texts[3]
            }
        }

        print("\nJSON OUTPUT:")

        print(
            json.dumps(
                question_json,
                indent=2
            )
        )

        with open(
            f"level_{game.current_level}.json",
            "w"
        ) as f:

            json.dump(
                question_json,
                f,
                indent=2
            )

        print(
            f"Saved level_{game.current_level}.json"
        )
        return

        game.refresh_state()

        # Get time remaining (timer starts after Option D is fetched)
        time_left = game.time_remaining
        if time_left is not None:
            print(f"\nTime remaining: {time_left:.1f}s")

        # Get answer
        answer_input = input("\nYour answer (A/B/C/D): ").strip().upper()
        if answer_input not in option_map:
            print("Invalid input. Please enter A, B, C, or D.")
            continue

        answer_id = option_map[answer_input]
        result = game.answer(answer_id)

        # Handle timeout
        if result.timed_out or result.status == "timeout":
            print(" TIME'S UP!")
            print(f"\n Game Over! You ran out of time.")
            print(f" Final earnings: ${result.earned_amount:,.2f}")
            break

        if result.correct:
            print(" CORRECT!")
            if result.game_over:
                print(f"\n CONGRATULATIONS! You completed the game!")
                print(f" Final earnings: ${result.earned_amount:,.2f}")
            else:
                print(f" Earned so far: ${result.earned_amount:,.2f}")
        else:
            print(" WRONG!")
            print(f"\n Game Over!")
            print(f" Final earnings: ${result.earned_amount:,.2f}")
    print("\n=== Game Summary ===")
    print(f"Reached Level: {game.current_level}")
    print(f"Total Earnings: ${game.earned_amount:,.2f}")

# %%
# Start speech mode game
print("\n=== Starting Game (With mode selection)===")
game = client.game.start(competition_id=comp_id, mode="speech")
print(f"Session ID: {game.session_id}")
print(f"Mode: {game.mode}")
print()
play_game(game)
# Out:
# === Starting Game (With mode selection)===
# Session ID: 187083
# Mode: speech
#
#
# --- Level 1 ---
# Fetching question audio...
#   Saved: level_1_question.wav
# Question saved
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# QUESTION:
#  What was Nero's primary method for gaining popularity among the lower class citizens of Rome?
# Fetching option A audio...
#   Saved: level_1_option_A.wav
# Fetching option B audio...
#   Saved: level_1_option_B.wav
# Fetching option C audio...
#   Saved: level_1_option_C.wav
# Fetching option D audio...
#   Saved: level_1_option_D.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Transcribing...
# Option A: Option A, Promoting Public Entertainments.
# Option B: Option B, Building New Temples.
# Option C: Option C, reducing taxes for the wealthy.
# Option D: Option D, increasing military spending.
#
# JSON OUTPUT:
# {
#   "question": " What was Nero's primary method for gaining popularity among the lower class citizens of Rome?",
#   "options": {
#     "A": "Option A, Promoting Public Entertainments.",
#     "B": "Option B, Building New Temples.",
#     "C": "Option C, reducing taxes for the wealthy.",
#     "D": "Option D, increasing military spending."
#   }
# }
# Saved level_1.json

# %%
print(game)
print(vars(game))
# Out:
# <millionaire_client.game.GameSession object at 0x7db1fa25a7e0>
# {'_client': <millionaire_client.base.BaseClient object at 0x7db1f95d7200>, '_state': GameState(session_id=186616, competition=Competition(id=1, name='Ancient History and Politics', description=None, max_levels=15, is_infinite=False, created_at=None, question_count=None), status=<GameStatus.IN_PROGRESS: 'in_progress'>, earned_amount=0, current_level=1, money_pyramid=[MoneyLevel(level=1, amount=100), MoneyLevel(level=2, amount=200), MoneyLevel(level=3, amount=300), MoneyLevel(level=4, amount=500), MoneyLevel(level=5, amount=1000), MoneyLevel(level=6, amount=2000), MoneyLevel(level=7, amount=4000), MoneyLevel(level=8, amount=8000), MoneyLevel(level=9, amount=16000), MoneyLevel(level=10, amount=32000), MoneyLevel(level=11, amount=64000), MoneyLevel(level=12, amount=128000), MoneyLevel(level=13, amount=256000), MoneyLevel(level=14, amount=512000), MoneyLevel(level=15, amount=1024000)], question_deadline=datetime.datetime(2026, 5, 24, 17, 34, 7, 29000, tzinfo=datetime.timezone.utc), question=Question(id=1235, text='What is the primary function of the Parthenon in ancient times?', options=[Option(id=0, text='A military fortress for Athens'), Option(id=1, text='A treasury for the Delian League'), Option(id=2, text='A temple dedicated to Athena'), Option(id=3, text='A residential palace for the king of Athens')], level=0), max_level=15, mode='text')}

# %% [markdown]
# In speech mode, the 30 seconds timer is starting when we are requesting the last option!!

# %%
# Show leaderboard position (speech mode)
lb = client.leaderboard.get(competition_id=comp_id, limit=10, mode="speech") # <---- include mode!!
print(f"\n=== Speech Leaderboard for {lb.competition.name} ===")
for i, entry in enumerate(lb.entries[:5], 1):
    marker = " <-- YOU" if entry.username == username else ""
    print(f"  {i}. {entry.username}: ${entry.score:,.2f} (Level {entry.reached_level}){marker}")
# Out:
# === Speech Leaderboard for Ancient History and Politics ===
#   1. gabrielep: $1,024,000.00 (Level 15)
#   2. Zero37: $1,024,000.00 (Level 15)
#   3. Vercingetorige: $1,024,000.00 (Level 15)
#   4. TheLastGuessbender: $1,024,000.00 (Level 15)
#   5. grepapetti: $512,000.00 (Level 14)
